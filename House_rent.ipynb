# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
df = pd.read_csv('train.csv')

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000
#
#            ...         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count      ...        1460.000000  1460.000000    1460.000000  1460.000000
# mean       ...          94.244521    46.660274      21.954110     3.409589
# std        ...         125.338794    66.256028      61.119149    29.317331
# min        ...           0.000000     0.000000       0.000000     0.000000
# 25%        ...           0.000000     0.000000       0.000000     0.000000
# 50%        ...           0.000000    25.000000       0.000000     0.000000
# 75%        ...         168.000000    68.000000       0.000000     0.000000
# max        ...         857.000000   547.000000     552.000000   508.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold  \
# count  1460.000000  1460.000000   1460.000000  1460.000000  1460.000000
# mean     15.060959     2.758904     43.489041     6.321918  2007.815753
# std      55.757415    40.177307    496.123024     2.703626     1.328095
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     5.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     480.000000   738.000000  15500.000000    12.000000  2010.000000
#
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000
#
# [8 rows x 38 columns]

# %%
df.columns
# Out:
# Index([u'Id', u'MSSubClass', u'MSZoning', u'LotFrontage', u'LotArea',
#        u'Street', u'Alley', u'LotShape', u'LandContour', u'Utilities',
#        u'LotConfig', u'LandSlope', u'Neighborhood', u'Condition1',
#        u'Condition2', u'BldgType', u'HouseStyle', u'OverallQual',
#        u'OverallCond', u'YearBuilt', u'YearRemodAdd', u'RoofStyle',
#        u'RoofMatl', u'Exterior1st', u'Exterior2nd', u'MasVnrType',
#        u'MasVnrArea', u'ExterQual', u'ExterCond', u'Foundation', u'BsmtQual',
#        u'BsmtCond', u'BsmtExposure', u'BsmtFinType1', u'BsmtFinSF1',
#        u'BsmtFinType2', u'BsmtFinSF2', u'BsmtUnfSF', u'TotalBsmtSF',
#        u'Heating', u'HeatingQC', u'CentralAir', u'Electrical', u'1stFlrSF',
#        u'2ndFlrSF', u'LowQualFinSF', u'GrLivArea', u'BsmtFullBath',
#        u'BsmtHalfBath', u'FullBath', u'HalfBath', u'BedroomAbvGr',
#        u'KitchenAbvGr', u'KitchenQual', u'TotRmsAbvGrd', u'Functional',
#        u'Fireplaces', u'FireplaceQu', u'GarageType', u'GarageYrBlt',
#        u'GarageFinish', u'GarageCars', u'GarageArea', u'GarageQual',
#        u'GarageCond', u'PavedDrive', u'WoodDeckSF', u'OpenPorchSF',
#        u'EnclosedPorch', u'3SsnPorch', u'ScreenPorch', u'PoolArea', u'PoolQC',
#        u'Fence', u'MiscFeature', u'MiscVal', u'MoSold', u'YrSold', u'SaleType',
#        u'SaleCondition', u'SalePrice'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# RoofMatl         1460 non-null object
# Exterior1st      1460 non-null object
# Exterior2nd      1460 non-null object
# MasVnrType       1452 non-null object
# MasVnrArea       1452 non-null float64
# ExterQual        1460 non-null object
# ExterCond        1460 non-null object
# Foundation       1460 non-null object
# BsmtQual         1423 non-null object
# BsmtCond         1423 non-null object
# BsmtExposure     1422 non-null object
# BsmtFinType1     1423 non-null object
# BsmtFinSF1       1460 non-null int64
# BsmtFinType2     1422 non-null object
# BsmtFinSF2       1460 non-null int64
# BsmtUnfSF        1460 non-null int64
# TotalBsmtSF      1460 non-null int64
# Heating          1460 non-null object
# HeatingQC        1460 non-null object
# CentralAir       1460 non-null object
# Electrical       1459 non-null object
# 1stFlrSF         1460 non-null int64
# 2ndFlrSF         1460 non-null int64
# LowQualFinSF     1460 non-null int64
# GrLivArea        1460 non-null int64
# BsmtFullBath     1460 non-null int64
# BsmtHalfBath     1460 non-null int64
# FullBath         1460 non-null int64
# HalfBath         1460 non-null int64
# BedroomAbvGr     1460 non-null int64
# KitchenAbvGr     1460 non-null int64
# KitchenQual      1460 non-null object
# TotRmsAbvGrd     1460 non-null int64
# Functional       1460 non-null object
# Fireplaces       1460 non-null int64
# FireplaceQu      770 non-null object
# GarageType       1379 non-null object
# GarageYrBlt      1379 non-null float64
# GarageFinish     1379 non-null object
# GarageCars       1460 non-null int64
# GarageArea       1460 non-null int64
# GarageQual       1379 non-null object
# GarageCond       1379 non-null object
# PavedDrive       1460 non-null object
# WoodDeckSF       1460 non-null int64
# OpenPorchSF      1460 non-null int64
# EnclosedPorch    1460 non-null int64
# 3SsnPorch        1460 non-null int64
# ScreenPorch      1460 non-null int64
# PoolArea         1460 non-null int64
# PoolQC           7 non-null object
# Fence            281 non-null object
# MiscFeature      54 non-null object
# MiscVal          1460 non-null int64
# MoSold           1460 non-null int64
# YrSold           1460 non-null int64
# SaleType         1460 non-null object
# SaleCondition    1460 non-null object
# SalePrice        1460 non-null int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
df.isnull().sum(axis=0)
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
#                  ...
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageCars          0
# GarageArea          0
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# MiscVal             0
# MoSold              0
# YrSold              0
# SaleType            0
# SaleCondition       0
# SalePrice           0
# Length: 81, dtype: int64

# %%
df.isnull().sum(axis=1).value_counts()
# Out:
# 4     635
# 5     501
# 3     132
# 10     60
# 6      58
# 9      32
# 2      16
# 11      7
# 8       5
# 7       5
# 15      4
# 14      3
# 1       2
# dtype: int64

# %% [markdown]
# ## Saleprice

# %%
df.SalePrice.hist()

# %% [markdown]
# The sale price has a high variance. We will take a log of the price as the target

# %%
df['SalePrice'] = np.log(df['SalePrice'])

# %%
df.SalePrice.hist()

# %%
df['SalePrice'] = (df['SalePrice'] - df['SalePrice'].mean())/(df['SalePrice'].max() - df['SalePrice'].min())

# %% [markdown]
# ## Lot frontage

# %%
df.LotFrontage.hist()

# %%
df.plot('LotFrontage','SalePrice', style='o')

# %%
df['LotFrontage'] = np.log(df['LotFrontage'])

# %%
df.LotFrontage.hist(bins=20)

# %% [markdown]
# There seems to be a linear patten of LotFrontage with SalePrice.
# We can fill the missing values either by -
# 1. Regressing these features and fill the missing values with prediction
# 2. Sample from the normal distribution of LotFrontage
#
# We will follow the second one.

# %%
LotFrontage_avg = df['LotFrontage'].mean()
LotFrontage_std = df['LotFrontage'].std()
LotFrontage_null_count = df['LotFrontage'].isnull().sum()
    
age_null_random_list = np.random.normal(loc=LotFrontage_avg, scale=LotFrontage_std, size=LotFrontage_null_count)
df['LotFrontage'][np.isnan(df['LotFrontage'])] = age_null_random_list
#dataset['custAge'] = dataset['custAge'].astype(int)
# Out:
# /Users/pkjain/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df['LotFrontage'] = (df['LotFrontage'] - df['LotFrontage'].mean())/(df['LotFrontage'].max() - df['LotFrontage'].min())

# %%
df.plot('LotFrontage','SalePrice', style='o')

# %%
df.LotFrontage.hist()

# %% [markdown]
# ## Alley

# %%
df.Alley.unique()
# Out:
# array([nan, 'Grvl', 'Pave'], dtype=object)

# %% [markdown]
# Alley has most of the data missing. We will ignore Alley

# %%
df.drop('Alley', axis=1, inplace=True)

# %% [markdown]
# ## MasVnrType

# %%
df['MasVnrType'].value_counts()
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
df.MasVnrType.isnull().sum()
# Out:
# 8

# %% [markdown]
# There are only 8 missing values and majority of the houses have None. We will replace the null values with None and treat None as a seaparate category.

# %%
df.ix[df.MasVnrType.isnull(), 'MasVnrType'] = 'None'
# Out:
# /Users/pkjain/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if __name__ == '__main__':

# %%
MasVnrType_dummy = pd.get_dummies(df['MasVnrType'], prefix='MasVnrType',drop_first=True)
df = df.join(MasVnrType_dummy)

# %%
df.boxplot('SalePrice',by='MasVnrType')

# %% [markdown]
# ## MasVnrArea

# %%
df.MasVnrArea.hist()

# %%
df.MasVnrArea.apply(lambda x: np.log(1+x)).hist()

# %% [markdown]
# The missing are same as MasVnrType. We will replace with the majority ones = 0

# %%
df.ix[df.MasVnrArea.isnull(), 'MasVnrArea'] = 0
# Out:
# /Users/pkjain/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if __name__ == '__main__':

# %%
df['MasVnrArea'] = np.log1p(df.MasVnrArea)

# %% [markdown]
# ## BsmtQual

# %%
df.BsmtQual.unique()
# Out:
# array(['Gd', 'TA', 'Ex', nan, 'Fa'], dtype=object)

# %%
df.BsmtQual.value_counts()
# Out:
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64

# %% [markdown]
# From Data description, the categories are ordered.

# %%
df.ix[df.BsmtQual.isnull(), 'BsmtQual'] = 'NA'

# %%
df['BsmtQual'] = df['BsmtQual'].map({'NA':0,'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}).astype('int')

# %%
df.boxplot('SalePrice',by='BsmtQual')

# %% [markdown]
# ## BsmtCond

# %%
df.BsmtCond.unique()
# Out:
# array(['TA', 'Gd', nan, 'Fa', 'Po'], dtype=object)

# %%
df.ix[df.BsmtCond.isnull(), 'BsmtCond'] = 'NA'
df['BsmtCond'] = df['BsmtCond'].map({'NA':0,'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}).astype('int')
df.boxplot('SalePrice',by='BsmtCond')

# %%
df['BsmtCond'].corr(df['BsmtQual'])
# Out:
# 0.63371341252756475

# %% [markdown]
# ## BsmtExposure

# %%
df.BsmtExposure.value_counts()
# Out:
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: BsmtExposure, dtype: int64

# %%
df.ix[df.BsmtExposure.isnull(), 'BsmtExposure'] = 'NA'
df['BsmtExposure'] = df['BsmtExposure'].map({'NA':0,'No':1, 'Mn':2, 'Av':3, 'Gd':4}).astype('int')
df.boxplot('SalePrice',by='BsmtExposure')

# %% [markdown]
# ## BsmtFinType1

# %%
df.BsmtFinType1.value_counts()
# Out:
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: BsmtFinType1, dtype: int64

# %%
df.ix[df.BsmtFinType1.isnull(), 'BsmtFinType1'] = 'NA'
df['BsmtFinType1'] = df['BsmtFinType1'].map({'NA':0,'Unf':1, 'LwQ':2, 'Rec':3, 'BLQ':4, 'ALQ':5, 'GLQ':6}).astype('int')
df.boxplot('SalePrice',by='BsmtFinType1')

# %% [markdown]
# ## BsmtFinSF1

# %%
df.BsmtFinSF1.hist()

# %%
df.BsmtFinSF1.apply(lambda x: np.log(1+x)).hist()

# %%
df['BsmtFinSF1'] = np.log1p(df.BsmtFinSF1)

# %% [markdown]
# ## BsmtFinType2

# %%
df.BsmtFinType2.value_counts()
# Out:
# Unf    1256
# Rec      54
# LwQ      46
# BLQ      33
# ALQ      19
# GLQ      14
# Name: BsmtFinType2, dtype: int64

# %%
df.ix[df.BsmtFinType2.isnull(), 'BsmtFinType2'] = 'NA'
df['BsmtFinType2'] = df['BsmtFinType2'].map({'NA':0,'Unf':1, 'LwQ':2, 'Rec':3, 'BLQ':4, 'ALQ':5, 'GLQ':6}).astype('int')
df.boxplot('SalePrice',by='BsmtFinType2')

# %% [markdown]
# ## BsmtFinSF2

# %%
df.BsmtFinSF2.hist()

# %%
df.BsmtFinSF2.apply(lambda x: np.log(1+x)).hist()

# %%
df['BsmtFinSF2'] = np.log1p(df.BsmtFinSF2)

# %% [markdown]
# ## Electrical

# %%
df.Electrical.value_counts()
# Out:
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64

# %%
df.ix[df.Electrical.isnull(),'Electrical'] = 'SBrkr'

# %%
df['Electrical'] = df['Electrical'].map({'Mix':0,'FuseP':1, 'FuseF':2, 'FuseA':3, 'SBrkr':4}).astype('int')
df.boxplot('SalePrice',by='Electrical')

# %% [markdown]
# ## FireplaceQu

# %%
df.FireplaceQu.unique()
# Out:
# array([nan, 'TA', 'Gd', 'Fa', 'Ex', 'Po'], dtype=object)

# %%
df.ix[df.FireplaceQu.isnull(), 'FireplaceQu'] = 'NA'
df['FireplaceQu'] = df['FireplaceQu'].map({'NA':0,'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}).astype('int')
df.boxplot('SalePrice',by='FireplaceQu')

# %% [markdown]
# ## GarageType

# %%
df.GarageType.value_counts()
# Out:
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64

# %%
df.ix[df.GarageType.isnull(), 'GarageType'] = 'NA'
df['GarageType'] = df['GarageType'].map({'NA':0,'Detchd':1, 'CarPort':2, 'BuiltIn':3, 'Basment':4, 'Attchd':5, '2Types':6}).astype('int')
df.boxplot('SalePrice',by='GarageType')

# %% [markdown]
# ## GarageYrBlt

# %%
df.GarageYrBlt.hist()

# %%
df[df.GarageYrBlt.isnull()].SalePrice.hist()

# %%
df.ix[df.GarageYrBlt.isnull(),'GarageYrBlt'] = df.GarageYrBlt.median()

# %%
df.GarageYrBlt.describe()
# Out:
# count    1460.000000
# mean     1978.589041
# std        23.997022
# min      1900.000000
# 25%      1962.000000
# 50%      1980.000000
# 75%      2001.000000
# max      2010.000000
# Name: GarageYrBlt, dtype: float64

# %%
_,gbins = pd.qcut(df.GarageYrBlt,5,retbins=True)

# %%
gbins
# Out:
# array([ 1900.,  1958.,  1975.,  1990.,  2003.,  2010.])

# %%
if 0:
    df.ix[df.GarageYrBlt <= 1957,'GarageYrBlt'] = 1
    df.ix[(df.GarageYrBlt > 1957) & (df.GarageYrBlt <=1973),'GarageYrBlt'] = 2
    df.ix[(df.GarageYrBlt > 1973) & (df.GarageYrBlt <=1993),'GarageYrBlt'] = 3
    df.ix[(df.GarageYrBlt > 1993) & (df.GarageYrBlt <=2004),'GarageYrBlt'] = 4
    df.ix[(df.GarageYrBlt > 2004) & (df.GarageYrBlt <=2010),'GarageYrBlt'] = 5
    df.ix[(df.GarageYrBlt > 2010),'GarageYrBlt'] = 6
    df.ix[df.GarageYrBlt.isnull(),'GarageYrBlt'] = 0

# %%
df['GarageYrBlt'] = df['GarageYrBlt'].astype(int)

# %% [markdown]
# ## GarageFinish

# %%
df.ix[df.GarageFinish.isnull(), 'GarageFinish'] = 'NA'
df['GarageFinish'] = df['GarageFinish'].map({'NA':0,'Unf':1, 'RFn':2, 'Fin':3}).astype('int')
df.boxplot('SalePrice',by='GarageFinish')

# %% [markdown]
# ## GarageArea

# %%
df.GarageArea.hist()

# %%
df['GarageArea'] = np.log1p(df.GarageArea)

# %% [markdown]
# ## GarageQual

# %%
df.GarageQual.value_counts()
# Out:
# TA    1311
# Fa      48
# Gd      14
# Ex       3
# Po       3
# Name: GarageQual, dtype: int64

# %%
df.ix[df.GarageQual.isnull(), 'GarageQual'] = 'NA'
df['GarageQual'] = df['GarageQual'].map({'NA':0,'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}).astype('int')
df.boxplot('SalePrice',by='GarageQual')

# %% [markdown]
# ## GarageCond

# %%
df.GarageCond.value_counts()
# Out:
# TA    1326
# Fa      35
# Gd       9
# Po       7
# Ex       2
# Name: GarageCond, dtype: int64

# %%
df.ix[df.GarageCond.isnull(), 'GarageCond'] = 'NA'
df['GarageCond'] = df['GarageCond'].map({'NA':0,'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}).astype('int')
df.boxplot('SalePrice',by='GarageCond')

# %% [markdown]
# ## PoolQC and PoolArea

# %% [markdown]
# Most of the entries do not have pools. We will ignore these two variables

# %%
df.PoolArea.hist()

# %%
df.drop(['PoolQC','PoolArea'], axis=1, inplace=True)

# %% [markdown]
# ## Fence

# %%
df.Fence.value_counts()
# Out:
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: Fence, dtype: int64

# %%
df.ix[df.Fence.isnull(),'Fence']='NA'
df['Fence'] = df['Fence'].map({'NA':0,'MnWw':1, 'GdWo':2, 'MnPrv':3, 'GdPrv':4}).astype('int')
df.boxplot('SalePrice',by='Fence')

# %%
df.boxplot('SalePrice',by='Fence')

# %% [markdown]
# ## MiscFeature

# %%
df.MiscFeature.value_counts()
# Out:
# Shed    49
# Othr     2
# Gar2     2
# TenC     1
# Name: MiscFeature, dtype: int64

# %% [markdown]
# This feature can be ignored

# %%
df.drop('MiscFeature',axis=1,inplace=True)

# %% [markdown]
# ## MSZoning

# %%
df.MSZoning.value_counts()
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
df.boxplot('SalePrice',by='MSZoning')

# %% [markdown]
# The test data has 4 missing values. We will replace them by *RL*

# %%
df.ix[df.MSZoning.isnull(),'MSZoning'] = 'RL'

# %%
MSZoning_dummy = pd.get_dummies(df['MSZoning'], prefix='MSZoning',drop_first=True)
df = df.join(MSZoning_dummy)

# %% [markdown]
# ## Street

# %%
df.Street.value_counts()
# Out:
# Pave    1454
# Grvl       6
# Name: Street, dtype: int64

# %%
df.boxplot('SalePrice',by='Street')

# %%
df['Street'] = df['Street'].map({'Pave':0,'Grvl':1}).astype('int')

# %% [markdown]
# ## LotShape

# %%
df.LotShape.value_counts()
# Out:
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64

# %%
df['LotShape'] = df['LotShape'].map({'IR3':0,'IR2':1,'IR1':2, 'Reg':3}).astype('int')

# %%
df.boxplot('SalePrice',by='LotShape')

# %% [markdown]
# ## LandContour

# %%
df.LandContour.value_counts()
# Out:
# Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# Name: LandContour, dtype: int64

# %%
df['LandContour'] = df['LandContour'].map({'Low':0,'HLS':1,'Bnk':2, 'Lvl':3}).astype('int')

# %%
df.boxplot('SalePrice',by='LandContour')

# %% [markdown]
# ## Utilities

# %%
df.Utilities.value_counts()
# Out:
# AllPub    1459
# NoSeWa       1
# Name: Utilities, dtype: int64

# %% [markdown]
# We will ignore this column.

# %%
df.drop('Utilities', axis=1, inplace=True)

# %% [markdown]
# ## LotConfig

# %%
df.LotConfig.value_counts()
# Out:
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: LotConfig, dtype: int64

# %%
df.boxplot('SalePrice',by='LotConfig')

# %% [markdown]
# LotConfig does not look important

# %%
df.drop('LotConfig', axis=1, inplace=True)

# %% [markdown]
# ## LandSlope

# %%
df.LandSlope.value_counts()
# Out:
# Gtl    1382
# Mod      65
# Sev      13
# Name: LandSlope, dtype: int64

# %%
df['LandSlope'] = df['LandSlope'].map({'Sev':0,'Mod':1,'Gtl':2}).astype('int')

# %%
df.boxplot('SalePrice',by='LandSlope')

# %% [markdown]
# ## Neighborhood

# %%
df.Neighborhood.value_counts()
# Out:
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# SWISU       25
# StoneBr     25
# MeadowV     17
# Blmngtn     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: Neighborhood, dtype: int64

# %%
df.boxplot('SalePrice',by='Neighborhood', rot=90)

# %%
Neighborhood_dummy = pd.get_dummies(df['Neighborhood'], prefix='Neighborhood',drop_first=True)
df = df.join(Neighborhood_dummy)

# %% [markdown]
# ## Condition1

# %%
df.Condition1.value_counts()
# Out:
# Norm      1260
# Feedr       81
# Artery      48
# RRAn        26
# PosN        19
# RRAe        11
# PosA         8
# RRNn         5
# RRNe         2
# Name: Condition1, dtype: int64

# %%
df.boxplot('SalePrice',by='Condition1')

# %%
df.ix[df.Condition1=='PosA','Condition1'] = 'Pos'
df.ix[df.Condition1=='PosN','Condition1'] = 'Pos'
df.ix[df.Condition1=='RRAn','Condition1'] = 'RRNS'
df.ix[df.Condition1=='RRNn','Condition1'] = 'RRNS'
df.ix[df.Condition1=='RRNe','Condition1'] = 'RREW'
df.ix[df.Condition1=='RRAe','Condition1'] = 'RREW'
# Out:
# /Users/pkjain/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if __name__ == '__main__':

# %%
Condition1_dummy = pd.get_dummies(df['Condition1'], prefix='Condition1',drop_first=True)
df = df.join(Condition1_dummy)

# %% [markdown]
# ## Condition2

# %%
df.Condition2.value_counts()
# Out:
# Norm      1445
# Feedr        6
# Artery       2
# RRNn         2
# PosN         2
# RRAn         1
# RRAe         1
# PosA         1
# Name: Condition2, dtype: int64

# %% [markdown]
# We will ignore Condition2

# %%
df.drop('Condition2',axis=1, inplace=True)

# %% [markdown]
# ## BldgType

# %%
df.BldgType.value_counts()
# Out:
# 1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: BldgType, dtype: int64

# %%
df.boxplot('SalePrice',by='BldgType')

# %%
BldgType_dummy = pd.get_dummies(df['BldgType'], prefix='BldgType',drop_first=True)
df = df.join(BldgType_dummy)

# %% [markdown]
# ## HouseStyle

# %%
df.HouseStyle.value_counts()
# Out:
# 1Story    726
# 2Story    445
# 1.5Fin    154
# SLvl       65
# SFoyer     37
# 1.5Unf     14
# 2.5Unf     11
# 2.5Fin      8
# Name: HouseStyle, dtype: int64

# %%
df.boxplot('SalePrice',by='HouseStyle')

# %%
HouseStyle_dummy = pd.get_dummies(df['HouseStyle'], prefix='HouseStyle',drop_first=True)
df = df.join(HouseStyle_dummy)

# %% [markdown]
# ## RoofStyle

# %%
df.RoofStyle.value_counts()
# Out:
# Gable      1141
# Hip         286
# Flat         13
# Gambrel      11
# Mansard       7
# Shed          2
# Name: RoofStyle, dtype: int64

# %%
df.boxplot('SalePrice',by='RoofStyle')

# %%
RoofStyle_dummy = pd.get_dummies(df['RoofStyle'], prefix='RoofStyle',drop_first=True)
df = df.join(RoofStyle_dummy)

# %% [markdown]
# ## RoofMat1

# %%
df.RoofMatl.value_counts()
# Out:
# CompShg    1434
# Tar&Grv      11
# WdShngl       6
# WdShake       5
# Membran       1
# Metal         1
# ClyTile       1
# Roll          1
# Name: RoofMatl, dtype: int64

# %% [markdown]
# We can ignore this column

# %%
df.drop('RoofMatl', axis=1, inplace=True)

# %% [markdown]
# ## Exterior1st

# %%
df.Exterior1st.value_counts()
# Out:
# VinylSd    515
# HdBoard    222
# MetalSd    220
# Wd Sdng    206
# Plywood    108
# CemntBd     61
# BrkFace     50
# WdShing     26
# Stucco      25
# AsbShng     20
# Stone        2
# BrkComm      2
# AsphShn      1
# ImStucc      1
# CBlock       1
# Name: Exterior1st, dtype: int64

# %%
df.boxplot('SalePrice',by='Exterior1st', rot=90)

# %%
df.ix[df.Exterior1st == 'Stone','Exterior1st'] = 'Other'
df.ix[df.Exterior1st == 'BrkComm','Exterior1st'] = 'Other'
df.ix[df.Exterior1st == 'AsphShn','Exterior1st'] = 'Other'
df.ix[df.Exterior1st == 'ImStucc','Exterior1st'] = 'Other'
df.ix[df.Exterior1st == 'CBlock','Exterior1st'] = 'Other'
# Out:
# /Users/pkjain/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if __name__ == '__main__':

# %%
Exterior1st_dummy = pd.get_dummies(df['Exterior1st'], prefix='Exterior1st',drop_first=True)
df = df.join(Exterior1st_dummy)

# %% [markdown]
# ## Exterior2nd

# %%
df.Exterior2nd.value_counts()
# Out:
# VinylSd    504
# MetalSd    214
# HdBoard    207
# Wd Sdng    197
# Plywood    142
# CmentBd     60
# Wd Shng     38
# Stucco      26
# BrkFace     25
# AsbShng     20
# ImStucc     10
# Brk Cmn      7
# Stone        5
# AsphShn      3
# Other        1
# CBlock       1
# Name: Exterior2nd, dtype: int64

# %%
df.boxplot('SalePrice',by='Exterior2nd', rot=90)

# %%
df.ix[df.Exterior2nd == 'Stone','Exterior2nd'] = 'Other'
df.ix[df.Exterior2nd == 'Brk Cmn','Exterior2nd'] = 'Other'
df.ix[df.Exterior2nd == 'AsphShn','Exterior2nd'] = 'Other'
df.ix[df.Exterior2nd == 'ImStucc','Exterior2nd'] = 'Other'
df.ix[df.Exterior2nd == 'CBlock','Exterior2nd'] = 'Other'
# Out:
# /Users/pkjain/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if __name__ == '__main__':

# %%
Exterior2nd_dummy = pd.get_dummies(df['Exterior2nd'], prefix='Exterior2nd',drop_first=True)
df = df.join(Exterior2nd_dummy)

# %% [markdown]
# ## ExterQual

# %%
df.ExterQual.value_counts()
# Out:
# TA    906
# Gd    488
# Ex     52
# Fa     14
# Name: ExterQual, dtype: int64

# %%
df['ExterQual'] = df['ExterQual'].map({'Po':0,'Fa':1,'TA':2, 'Gd':3, 'Ex':4}).astype('int')

# %%
df.boxplot('SalePrice',by='ExterQual', rot=90)

# %% [markdown]
# ## ExterCond

# %%
df.ExterCond.value_counts()
# Out:
# TA    1282
# Gd     146
# Fa      28
# Ex       3
# Po       1
# Name: ExterCond, dtype: int64

# %%
df['ExterCond'] = df['ExterCond'].map({'Po':0,'Fa':1,'TA':2, 'Gd':3, 'Ex':4}).astype('int')

# %%
df.boxplot('SalePrice',by='ExterCond', rot=90)

# %% [markdown]
# ## Foundation

# %%
df.Foundation.value_counts()
# Out:
# PConc     647
# CBlock    634
# BrkTil    146
# Slab       24
# Stone       6
# Wood        3
# Name: Foundation, dtype: int64

# %%
df.boxplot('SalePrice',by='Foundation', rot=90)

# %%
Foundation_dummy = pd.get_dummies(df['Foundation'], prefix='Foundation',drop_first=True)
df = df.join(Foundation_dummy)

# %% [markdown]
# ## Heating

# %%
df.Heating.value_counts()
# Out:
# GasA     1428
# GasW       18
# Grav        7
# Wall        4
# OthW        2
# Floor       1
# Name: Heating, dtype: int64

# %%
df.boxplot('SalePrice',by='Heating', rot=90)

# %%
Heating_dummy = pd.get_dummies(df['Heating'], prefix='Heating',drop_first=True)
df = df.join(Heating_dummy)

# %% [markdown]
# ## HeatingQC

# %%
df.HeatingQC.value_counts()
# Out:
# Ex    741
# TA    428
# Gd    241
# Fa     49
# Po      1
# Name: HeatingQC, dtype: int64

# %%
df['HeatingQC'] = df['HeatingQC'].map({'Po':0,'Fa':1,'TA':2, 'Gd':3, 'Ex':4}).astype('int')

# %%
df.boxplot('SalePrice',by='HeatingQC', rot=90)

# %% [markdown]
# ## CentralAir

# %%
df.CentralAir.value_counts()
# Out:
# Y    1365
# N      95
# Name: CentralAir, dtype: int64

# %%
df.boxplot('SalePrice',by='CentralAir', rot=90)

# %%
df['CentralAir'] = df['CentralAir'].map({'N':0,'Y':1}).astype('int')

# %% [markdown]
# ## KitchenQual

# %%
df.KitchenQual.value_counts()
# Out:
# TA    735
# Gd    586
# Ex    100
# Fa     39
# Name: KitchenQual, dtype: int64

# %%
df['KitchenQual'] = df['KitchenQual'].map({'Po':0,'Fa':1,'TA':2, 'Gd':3, 'Ex':4}).astype('int')

# %%
df.boxplot('SalePrice',by='KitchenQual', rot=90)

# %% [markdown]
# ## Functional

# %%
df.Functional.value_counts()
# Out:
# Typ     1360
# Min2      34
# Min1      31
# Mod       15
# Maj1      14
# Maj2       5
# Sev        1
# Name: Functional, dtype: int64

# %%
df['Functional'] = df['Functional'].map({'Sev':0,'Maj2':1,'Maj1':2, 'Mod':3, 'Min1':4,'Min2':5,'Typ':6}).astype('int')

# %%
df.boxplot('SalePrice',by='Functional', rot=90)

# %% [markdown]
# ## PavedDrive

# %%
df.PavedDrive.value_counts()
# Out:
# Y    1340
# N      90
# P      30
# Name: PavedDrive, dtype: int64

# %%
df['PavedDrive'] = df['PavedDrive'].map({'N':0,'P':1,'Y':2}).astype('int')

# %%
df.boxplot('SalePrice',by='PavedDrive', rot=90)

# %% [markdown]
# ## SaleType

# %%
df.SaleType.value_counts()
# Out:
# WD       1267
# New       122
# COD        43
# ConLD       9
# ConLw       5
# ConLI       5
# CWD         4
# Oth         3
# Con         2
# Name: SaleType, dtype: int64

# %%
df.boxplot('SalePrice',by='SaleType', rot=90)

# %%
SaleType_dummy = pd.get_dummies(df['SaleType'], prefix='SaleType',drop_first=True)
df = df.join(SaleType_dummy)

# %% [markdown]
# ## SaleCondition

# %%
df.SaleCondition.value_counts()
# Out:
# Normal     1198
# Partial     125
# Abnorml     101
# Family       20
# Alloca       12
# AdjLand       4
# Name: SaleCondition, dtype: int64

# %%
df.boxplot('SalePrice',by='SaleCondition', rot=90)

# %%
SaleCondition_dummy = pd.get_dummies(df['SaleCondition'], prefix='SaleCondition',drop_first=True)
df = df.join(SaleCondition_dummy)

# %%
df[['GarageType', 'GarageCars','GarageArea','GarageQual', 'GarageCond']].corr()
# Out:
#             GarageType  GarageCars  GarageArea  GarageQual  GarageCond
# GarageType    1.000000    0.445903    0.486568    0.461255    0.472196
# GarageCars    0.445903    1.000000    0.730110    0.576622    0.568408
# GarageArea    0.486568    0.730110    1.000000    0.931128    0.930324
# GarageQual    0.461255    0.576622    0.931128    1.000000    0.959172
# GarageCond    0.472196    0.568408    0.930324    0.959172    1.000000

# %%
df.plot('GarageArea','GarageCond', style='o')

# %% [markdown]
# Garage condition, quality are highly correlated. We can drop quality column

# %%
df.drop('GarageQual', axis=1, inplace=True)

# %% [markdown]
# ## LotArea

# %%
df.LotArea.hist()

# %%
df['LotArea'] = np.log(df['LotArea'])

# %% [markdown]
# ## TotalBsmtSF

# %%
df.TotalBsmtSF.hist()

# %%
df['TotalBsmtSF']=np.log1p(df['TotalBsmtSF'])

# %% [markdown]
# ## 1stFlrSF

# %%
df['1stFlrSF'].hist()

# %%
df['1stFlrSF']=np.log(df['1stFlrSF'])

# %% [markdown]
# ## 2ndFlrSF

# %%
df['2ndFlrSF'].hist()

# %%
df['2ndFlrSF']=np.log1p(df['2ndFlrSF'])

# %% [markdown]
# ## LowQualFinSF

# %%
df.LowQualFinSF.value_counts()
# Out:
# 0      1434
# 80        3
# 360       2
# 528       1
# 53        1
# 120       1
# 144       1
# 156       1
# 205       1
# 232       1
# 234       1
# 371       1
# 572       1
# 390       1
# 392       1
# 397       1
# 420       1
# 473       1
# 479       1
# 481       1
# 513       1
# 514       1
# 515       1
# 384       1
# Name: LowQualFinSF, dtype: int64

# %% [markdown]
# Most of the data has 0. We will drop this column

# %%
df.drop('LowQualFinSF', axis=1, inplace=True)

# %% [markdown]
# ## GrLivArea

# %%
df.GrLivArea.hist()

# %%
df['GrLivArea']=np.log(df['GrLivArea'])

# %%
df.plot('GrLivArea','SalePrice', style='o')

# %%
df['GrLivArea'] = (df['GrLivArea'] - df['GrLivArea'].mean())/(df['GrLivArea'].max() - df['GrLivArea'].min())

# %% [markdown]
# ## WoodDeckSF

# %%
df['WoodDeckSF'].hist()

# %%
df['WoodDeckSF'] = np.log1p(df['WoodDeckSF'])

# %% [markdown]
# ## OpenPorchSF

# %%
df['OpenPorchSF'].hist()

# %%
df['OpenPorchSF'] = np.log1p(df['OpenPorchSF'])

# %% [markdown]
# ## EnclosedPorch

# %%
df.EnclosedPorch.hist()

# %%
df['EnclosedPorch'] = np.log1p(df['EnclosedPorch'])

# %% [markdown]
# ## 3SsnPorch

# %%
df['3SsnPorch'].hist()

# %%
df.plot('3SsnPorch','SalePrice',style='o')

# %%
df['3SsnPorch'] = np.log1p(df['3SsnPorch'])

# %% [markdown]
# ## ScreenPorch

# %%
df.ScreenPorch.hist()

# %%
df['ScreenPorch'] = np.log1p(df['ScreenPorch'])

# %% [markdown]
# ## MiscVal

# %%
df.MiscVal.value_counts()
# Out:
# 0        1408
# 400        11
# 500         8
# 700         5
# 450         4
# 2000        4
# 600         4
# 1200        2
# 480         2
# 1150        1
# 800         1
# 15500       1
# 620         1
# 3500        1
# 560         1
# 2500        1
# 1300        1
# 1400        1
# 350         1
# 8300        1
# 54          1
# Name: MiscVal, dtype: int64

# %%
df.plot('MiscVal','SalePrice',style='o')

# %%
df['MiscVal'] = np.log1p(df['MiscVal'])

# %%
df.drop('MiscVal', axis=1, inplace=True)

# %% [markdown]
# ## MoSold

# %%
df.MoSold.hist()

# %%
df.boxplot('SalePrice',by='MoSold', rot=90)

# %% [markdown]
# ## YrSold

# %%
df.YrSold.hist()

# %% [markdown]
# ## KitchenAbvGr

# %%
df.KitchenAbvGr.value_counts()
# Out:
# 1    1392
# 2      65
# 3       2
# 0       1
# Name: KitchenAbvGr, dtype: int64

# %%
df.boxplot('SalePrice',by='KitchenAbvGr', rot=90)

# %% [markdown]
# ## Bedroom

# %%
df.BedroomAbvGr.value_counts()
# Out:
# 3    804
# 2    358
# 4    213
# 1     50
# 5     21
# 6      7
# 0      6
# 8      1
# Name: BedroomAbvGr, dtype: int64

# %%
df.boxplot('SalePrice',by='BedroomAbvGr', rot=90)

# %%
ordinal_columns = ['MSSubClass','LotFrontage','LotArea','LotShape','OverallQual','OverallCond', 'YearBuilt',
                  'YearRemodAdd', 'MasVnrArea','ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
                  'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','HeatingQC','1stFlrSF','2ndFlrSF',
                   'GrLivArea','BsmtFullBath','BsmtHalfBath','FullBath','HalfBath','BedroomAbvGr','KitchenAbvGr','KitchenQual',
                  'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageYrBlt','GarageFinish','GarageCars', 'GarageArea',
                  'GarageCond', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', 'Fence', 'MoSold', 'YrSold']

# %%
plt.figure(figsize=(10,10))
correlation1 = df[ordinal_columns].corr()
mask = np.zeros_like(correlation1)
indices = np.triu_indices_from(correlation1)
mask[indices] = True
cmap = sns.diverging_palette(220, 8, as_cmap=True)
ax1 =sns.heatmap(correlation1, vmin = -1, vmax = 1, \
    cmap = cmap, cbar = True)

# %%
## Model to be continued...

# %%
'SaleType' in df.columns
# Out:
# True

# %% [markdown]
# ## Train-test split

# %%
df.drop('Id', axis=1, inplace=True)

# %%
df.drop(['MasVnrType', 'MSZoning', 'Neighborhood', 'Condition1', 'BldgType', 'HouseStyle', 'RoofStyle', 'Exterior1st'], axis=1, inplace=True)
df.drop(['Exterior2nd', 'Foundation', 'Heating', 'SaleType', 'SaleCondition'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index([u'MSSubClass', u'LotFrontage', u'LotArea', u'Street', u'LotShape',
#        u'LandContour', u'LandSlope', u'OverallQual', u'OverallCond',
#        u'YearBuilt',
#        ...
#        u'SaleType_ConLI', u'SaleType_ConLw', u'SaleType_New', u'SaleType_Oth',
#        u'SaleType_WD', u'SaleCondition_AdjLand', u'SaleCondition_Alloca',
#        u'SaleCondition_Family', u'SaleCondition_Normal',
#        u'SaleCondition_Partial'],
#       dtype='object', length=151)

# %%
from sklearn.model_selection import train_test_split

def cross_validate(Xs, ys):
    X_train, X_test, y_train, y_test = train_test_split(
            Xs, ys, test_size=0.2, random_state=0)
    return X_train, X_test, y_train, y_test

# %%
train1_X = df.copy()
train1_X.drop('SalePrice', axis=1, inplace=True)
train1_Y = df['SalePrice'].copy()

X_train, X_test, y_train, y_test = cross_validate(train1_X, train1_Y)

X_train.reset_index(drop=True, inplace=True)
X_test.reset_index(drop=True, inplace=True)
y_train.reset_index(drop=True, inplace=True)
y_test.reset_index(drop=True, inplace=True)

# %%
X_train.shape
# Out:
# (1168, 150)

# %%
y_train.shape
# Out:
# (1168,)

# %% [markdown]
# ## Model development

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()
regr.fit(X_train, y_train)
print(regr.predict(X_test))
# Out:
# [ 0.10631308 -0.05513207 -0.07699422  0.10081545 -0.17487922 -0.19214074
#   0.14694075 -0.08038507  0.34677789 -0.00717237  0.04776335 -0.04942988
#   0.09537261 -0.11091453 -0.09922819 -0.05106468  0.13503327 -0.09868713
#  -0.07111855 -0.02292854 -0.08558112  0.01973107 -0.19198701 -0.02739574
#   0.02938292 -0.01080131 -0.00600512 -0.26660657  0.16886372 -0.12598354
#  -0.03922471  0.07704954 -0.03984954  0.20645731  0.23595934  0.05453771
#   0.16602727 -0.09751121  0.10676357  0.23080866  0.06672013 -0.096992
#   0.05800451  0.20593785  0.25134161 -0.05593337 -0.12699281 -0.09316324
#   0.01066108 -0.19598181  0.29081436 -0.03706995 -0.00334726 -0.21575578
#   0.08814845 -0.12754271 -0.13486016  0.08018045 -0.07763127 -0.29833065
#  -0.05073196 -0.08064306 -0.07748286 -0.03964291  0.06870222  0.01328567
#  -0.07941605  0.07457476 -0.08720626  0.06675302  0.04143543 -0.09157095
#  -0.30061036  0.16203836 -0.2224576   0.12198775 -0.08812008 -0.14730017
#   0.18054274  0.07217812 -0.09391316 -0.06888645 -0.10834848 -0.0451545
#   0.07940001  0.05244517 -0.18239201  0.08486681 -0.00304594 -0.04695895
#   0.03445324  0.03291162  0.01331917  0.11056196  0.03621817 -0.02006851
#   0.08242566 -0.00840891 -0.10263633 -0.0299478   0.12599495  0.05373955
#  -0.12918833 -0.05961885 -0.13830367  0.1742411   0.03484111 -0.19313017
#   0.01822261 -0.10729576 -0.1546784  -0.12491315  0.02825226 -0.10720931
#   0.04311145  0.00728952  0.27723963 -0.12305962  0.06619998  0.13695292
#  -0.02775563 -0.01912544 -0.09336686  0.01837726  0.08331663  0.13101632
#   0.25523811  0.0802335   0.05584631  0.001413    0.07366277  0.04061749
#  -0.05886567  0.06403811 -0.16364348  0.04106666 -0.04553756  0.00248611
#  -0.15589709  0.01301353  0.01645038 -0.09756864  0.13309778 -0.02549583
#  -0.03088874  0.00473308  0.08339767 -0.05603249  0.18357682  0.09594536
#  -0.01028865  0.22539768  0.14011887 -0.05398858 -0.03180804  0.15705785
#  -0.0757991   0.06215355 -0.0855685   0.00831893 -0.12489607 -0.08640426
#   0.06173342 -0.07857134  0.11858705 -0.12654858  0.00849184  0.15186304
#   0.10352107 -0.00844606 -0.02213315 -0.0095643   0.07216293  0.02644727
#  -0.12374677 -0.07730197 -0.0756828   0.09952511 -0.14940677 -0.05202601
#   0.15487363  0.04354187 -0.12342772  0.18705166 -0.14282099  0.04412594
#  -0.16638619  0.07486079  0.07975604 -0.05856455 -0.04336541  0.00804189
#   0.08979049 -0.06446605 -0.08967719 -0.05298449 -0.26899649 -0.01700221
#   0.00734679 -0.10774225 -0.10494934  0.06511027 -0.14092861 -0.11720678
#  -0.05772423  0.04728579 -0.02321898  0.192226    0.14384954 -0.26235376
#  -0.03375096  0.14422108 -0.18922302 -0.1335575   0.21241248 -0.01157951
#   0.02557376  0.13144265  0.13746735 -0.22940928  0.05393274 -0.0878523
#  -0.06559408 -0.07906467  0.05257302  0.17026592  0.08946851  0.04454796
#  -0.08627766 -0.02154114 -0.19256492 -0.02816908 -0.16573161 -0.03728572
#   0.16836523 -0.06036585 -0.07556343 -0.12367323 -0.23207811  0.02312654
#  -0.13163333  0.03949287  0.07392572  0.08852122  0.04783612  0.00416715
#   0.05940542  0.03826108 -0.00860556  0.06505577  0.03262058  0.15136635
#  -0.22214995  0.30984881  0.12053738  0.10470084 -0.12876978  0.09454236
#   0.27470746  0.46356486  0.04289368 -0.16010933 -0.08783504 -0.2254942
#   0.27858607  0.22960415  0.23897063 -0.28677783  0.11463147  0.11738044
#  -0.07643202  0.10712184 -0.04013585  0.02601429 -0.0880885   0.10127717
#   0.11165745  0.12585673  0.08129783 -0.24297805 -0.08389804  0.25895321
#  -0.00770785 -0.0590118   0.04740621 -0.05979847 -0.10201933  0.1836276
#   0.33502452  0.1132812  -0.18232457 -0.15383799]

# %%
regr.score(X_test,y_test)
# Out:
# 0.83913734359214143

# %%
import math
print("RMSE: %.2f"
      % math.sqrt(np.mean((regr.predict(X_test) - y_test) ** 2)))
# Out:
# RMSE: 0.05

# %% [markdown]
# ## XGBoost

# %%
from sklearn.metrics import explained_variance_score
import xgboost
from sklearn.model_selection import GridSearchCV, train_test_split
from xgboost import XGBRegressor
from sklearn.metrics import r2_score

# %%
# A parameter grid for XGBoost
#params = {'min_child_weight':[4,5], 'gamma':[i/10.0 for i in range(3,4)],  'subsample':[i/10.0 for i in range(6,9)],
#'colsample_bytree':[i/10.0 for i in range(6,9)], 'max_depth': [3,4]}
params = {'min_child_weight':[10],  'subsample':[0.5],
'colsample_bytree':[0.6], 'max_depth': [20], 'learning_rate': [0.01, 0.1], 'n_estimators':[2000]}

# Initialize XGB and GridSearch
xgb = XGBRegressor(nthread=-1) 

grid = GridSearchCV(xgb, params)
grid.fit(X_train, y_train)

# Print the r2 score
print(r2_score(y_test, grid.best_estimator_.predict(X_test)))
# Out:
# 0.893879170921

# %%
import xgboost as xg
max_depth = 3
min_child_weight = 10
subsample = 0.5
colsample_bytree = 0.7
objective = 'reg:linear'
num_estimators = 2000
learning_rate = 0.01

#features = df[feature_columns]
#target = df[target_columns]
clf = xg.XGBRegressor(max_depth=max_depth,
                min_child_weight=min_child_weight,
                subsample=subsample,
                colsample_bytree=colsample_bytree,
                objective=objective,
                n_estimators=num_estimators,
                learning_rate=learning_rate)
clf.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_delta_step=0,
#        max_depth=3, min_child_weight=10, missing=None, n_estimators=2000,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=0.5)

# %%
print "Training error = ", r2_score(y_train, clf.predict(X_train)) 

print "Testing error = ", r2_score(y_test, clf.predict(X_test))
# Out:
# Training error =  0.964088038221
# Testing error =  0.88780185707

# %%
from xgboost import plot_importance, to_graphviz
fig = plt.figure(figsize = (14, 20))
ax = fig.add_subplot(111)

colours = plt.cm.Set1(np.linspace(0, 1, 9))

ax = plot_importance(clf, height = 1, color = colours, grid = False, \
                     importance_type = 'cover', ax = ax);
for axis in ['top','bottom','left','right']:
            ax.spines[axis].set_linewidth(2)
        
ax.set_xlabel('importance score', size = 16);
ax.set_ylabel('features', size = 16);
ax.set_yticklabels(ax.get_yticklabels(), size = 12);
ax.set_title('Ordering of features by importance to the model learnt', size = 20);
